# %%
import pandas as pd

# %%
cities_df = pd.read_csv("cities.csv")

# %%
cities_df.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
cities_df = cities_df.reset_index()
cities_df.head()
# Out:
#    index  City_ID          City  Cloudiness Country        Date  Humidity  \
# 0      0        0  jacareacanga           0      BR  1528902000        62
# 1      1        1    kaitangata         100      NZ  1528905304        94
# 2      2        2      goulburn          20      AU  1528905078        91
# 3      3        3          lata          76      IN  1528905305        89
# 4      4        4    chokurdakh           0      RU  1528905306        88
#
#      Lat     Lng  Max Temp  Wind Speed
# 0  -6.22  -57.76     89.60        6.93
# 1 -46.28  169.85     42.61        5.64
# 2 -34.75  149.72     44.32       10.11
# 3  30.78   78.62     59.89        0.94
# 4  70.62  147.90     32.17        2.95

# %%
cities_df = cities_df.drop(columns=["index"])

# %%
cities_df.iloc[:19,:]
plt.savefig("testing testing")
# Out:
#     City_ID                City  Cloudiness Country        Date  Humidity  \
# 0         0        jacareacanga           0      BR  1528902000        62
# 1         1          kaitangata         100      NZ  1528905304        94
# 2         2            goulburn          20      AU  1528905078        91
# 3         3                lata          76      IN  1528905305        89
# 4         4          chokurdakh           0      RU  1528905306        88
# 5         5            martyush          92      RU  1528905306        94
# 6         6              hobart          20      AU  1528902000        87
# 7         7         broken hill           0      AU  1528905311        88
# 8         8           harnosand           0      SE  1528903200        44
# 9         9           tuatapere           0      NZ  1528905312       100
# 10       10        puerto ayora          90      EC  1528902000        69
# 11       11  havre-saint-pierre          75      CA  1528902000        58
# ...

# %%
fig = cities_df.plot().get_figure()

# %%
cities_df.plot()
